# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\dell\Desktop\rupesh\Data Science Courses\Ashish Pandey Classes\datasets\Bank_churn_modelling.csv")

# %%
data.shape
# Out:
# (10000, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
data=data.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# %%
data.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
data.head().T
# Out:
#                       0        1       2        3        4
# CreditScore         619      608     502      699      850
# Geography        France    Spain  France   France    Spain
# Gender           Female   Female  Female   Female   Female
# Age                  42       41      42       39       43
# Tenure                2        1       8        1        2
# Balance               0  83807.9  159661        0   125511
# NumOfProducts         1        1       3        2        1
# HasCrCard             1        0       1        0        1
# IsActiveMember        1        1       0        0        1
# EstimatedSalary  101349   112543  113932  93826.6  79084.1
# Exited                1        0       1        0        0

# %%
data.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
a=['CreditScore', 'Age', 'Tenure', 'Balance','NumOfProducts',  'EstimatedSalary']
b=['Geography', 'Gender', 'HasCrCard', 'IsActiveMember','Exited']

# %%
for i in b:
    print(data[i].describe())
    sns.countplot(x=i,data=data)
    plt.show()
# Out:
# count      10000
# unique         3
# top       France
# freq        5014
# Name: Geography, dtype: object
# count     10000
# unique        2
# top        Male
# freq       5457
# Name: Gender, dtype: object
# count    10000.00000
# mean         0.70550
# std          0.45584
# min          0.00000
# 25%          0.00000
# 50%          1.00000
# 75%          1.00000
# max          1.00000
# Name: HasCrCard, dtype: float64
# count    10000.000000
# mean         0.515100
# std          0.499797
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: IsActiveMember, dtype: float64
# count    10000.000000
# mean         0.203700
# std          0.402769
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: Exited, dtype: float64

# %%
for i in a:
    print(data[i].describe())
    print(data[i].skew())
    sns.distplot(data[i])
    plt.show()
# Out:
# count    10000.000000
# mean       650.528800
# std         96.653299
# min        350.000000
# 25%        584.000000
# 50%        652.000000
# 75%        718.000000
# max        850.000000
# Name: CreditScore, dtype: float64
# -0.07160660820092675
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: Age, dtype: float64
# 1.0113202630234552
# count    10000.000000
# mean         5.012800
# std          2.892174
# min          0.000000
# 25%          3.000000
# 50%          5.000000
# 75%          7.000000
# max         10.000000
# Name: Tenure, dtype: float64
# 0.01099145797717904
# count     10000.000000
# mean      76485.889288
# std       62397.405202
# min           0.000000
# 25%           0.000000
# 50%       97198.540000
# 75%      127644.240000
# max      250898.090000
# Name: Balance, dtype: float64
# -0.14110871094154384
# ...

# %%
data.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
a
# Out:
# ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']

# %%
b
# Out:
# ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember', 'Exited']

# %%
data['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
for i in b:
    c=pd.crosstab(data[i],data["Exited"], margins=True)
    print(c)
    print(c[1]/c["All"])
    sns.barplot(x=i,y="Exited",data=data)
    plt.show()
    sns.countplot(x=data[i],hue=data["Exited"])
    plt.show()
# Out:
# Exited        0     1    All
# Geography
# France     4204   810   5014
# Germany    1695   814   2509
# Spain      2064   413   2477
# All        7963  2037  10000
# Geography
# France     0.161548
# Germany    0.324432
# Spain      0.166734
# All        0.203700
# dtype: float64
# Exited     0     1    All
# Gender
# Female  3404  1139   4543
# Male    4559   898   5457
# All     7963  2037  10000
# Gender
# Female    0.250715
# Male      0.164559
# All       0.203700
# dtype: float64
# Exited        0     1    All
# HasCrCard
# 0          2332   613   2945
# 1          5631  1424   7055
# All        7963  2037  10000
# HasCrCard
# 0      0.208149
# 1      0.201843
# All    0.203700
# dtype: float64
# Exited             0     1    All
# IsActiveMember
# 0               3547  1302   4849
# 1               4416   735   5151
# All             7963  2037  10000
# IsActiveMember
# 0      0.268509
# 1      0.142691
# All    0.203700
# dtype: float64
# Exited     0     1    All
# Exited
# ...

# %%
for i in b:
    c=pd.crosstab(data[i],data["Exited"], margins=True)
    print(c)
    print(c[1]/c["All"])
    sns.barplot(x=i,y="Exited",data=data)
    plt.show()
# Out:
# Exited        0     1    All
# Geography
# France     4204   810   5014
# Germany    1695   814   2509
# Spain      2064   413   2477
# All        7963  2037  10000
# Geography
# France     0.161548
# Germany    0.324432
# Spain      0.166734
# All        0.203700
# dtype: float64
# Exited     0     1    All
# Gender
# Female  3404  1139   4543
# Male    4559   898   5457
# All     7963  2037  10000
# Gender
# Female    0.250715
# Male      0.164559
# All       0.203700
# dtype: float64
# Exited        0     1    All
# HasCrCard
# 0          2332   613   2945
# 1          5631  1424   7055
# All        7963  2037  10000
# HasCrCard
# 0      0.208149
# 1      0.201843
# All    0.203700
# dtype: float64
# Exited             0     1    All
# IsActiveMember
# 0               3547  1302   4849
# 1               4416   735   5151
# All             7963  2037  10000
# IsActiveMember
# 0      0.268509
# 1      0.142691
# All    0.203700
# dtype: float64
# Exited     0     1    All
# Exited
# ...

# %%
for i in a:
    sns.distplot(data[i][data["Exited"]==1],color='r')
    sns.distplot(data[i][data["Exited"]==0],color='y')
    plt.show()

# %% [markdown]
# Analysis
# High Important- Gender, Geography, Age, Balance, numofproduct
# Not important-  credit card, Estimated Salary
# Less Important - Credit Score, Tenure

# %% [markdown]
# Analysis: Existing rate for female customers is high
#           existing rate in germany is high
#           existing rate in high for customers who age is between 40-60
#           existing rate is high for customers those using 3 and 4 product
#           existing rate is high for customers who was not actively using bank services
#           existing rate is high for customers having high balance

# %% [markdown]
# multivariate operation here

# %%
g=data.groupby('Geography')

# %%
df=g.get_group("Germany")

# %%
df.head()
# Out:
#     CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 7           376   Germany  Female   29       4  115046.74              4
# 15          616   Germany    Male   45       3  143129.41              2
# 16          653   Germany    Male   58       1  132602.88              1
# 26          756   Germany    Male   36       2  136815.64              1
# 28          574   Germany  Female   43       3  141349.43              1
#
#     HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 7           1               0        119346.88       1
# 15          0               1         64327.26       0
# 16          1               0          5097.67       1
# 26          1               1        170041.95       0
# 28          1               1        100187.43       0

# %%
for i in b:
    c=pd.crosstab(df[i],df["Exited"], margins=True)
    print(c)
    print(c[1]/c["All"])
    sns.barplot(x=i,y="Exited",data=df)
    plt.show()
# Out:
# Exited        0    1   All
# Geography
# Germany    1695  814  2509
# All        1695  814  2509
# Geography
# Germany    0.324432
# All        0.324432
# dtype: float64
# Exited     0    1   All
# Gender
# Female   745  448  1193
# Male     950  366  1316
# All     1695  814  2509
# Gender
# Female    0.375524
# Male      0.278116
# All       0.324432
# dtype: float64
# Exited        0    1   All
# HasCrCard
# 0           481  237   718
# 1          1214  577  1791
# All        1695  814  2509
# HasCrCard
# 0      0.330084
# 1      0.322166
# All    0.324432
# dtype: float64
# Exited             0    1   All
# IsActiveMember
# 0                743  518  1261
# 1                952  296  1248
# All             1695  814  2509
# IsActiveMember
# 0      0.410785
# 1      0.237179
# All    0.324432
# dtype: float64
# Exited     0    1   All
# Exited
# 0       1695    0  1695
# 1          0  814   814
# All     1695  814  2509
# Exited
# 0      0.000000
# 1      1.000000
# ...

# %%
for i in a:
    sns.distplot(df[i][df["Exited"]==1],color='r')
    sns.distplot(df[i][df["Exited"]==0],color='y')
    plt.show()

# %%
for i in a:
    sns.boxplot(x="Exited",y=i,data=df)
    plt.show()

# %% [markdown]
# balance,exited,age

# %%
sns.scatterplot(x="Age",y="Balance",hue="Exited",data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %% [markdown]
# 1. balance between 75k-150k and age is 42-70 in Germany

# %%
sns.scatterplot(x="Age",y="Gender",hue="Exited",data=df)
plt.show()

# %%
sns.scatterplot(x="Age",y="Balance",hue="Gender",data=df)
plt.show()

# %% [markdown]
# No any pattern here

# %%
sns.scatterplot(x="CreditScore",y="Balance",hue="Gender",data=df)
plt.show()

# %%
sns.boxplot(x="Gender",y="Age",hue="Exited", data=df)
plt.show()

# %%
sns.boxplot(y="Balance",x="Gender",hue="Exited", data=df)
plt.show()
